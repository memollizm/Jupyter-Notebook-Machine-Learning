# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for sayi in [1,2,3,4,5]:
    print(sayi)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
data = {'isim': ['ahmet', 'mehmet'],
       'yas' : [25,65]}

# %%
data
# Out:
# {'isim': ['ahmet', 'mehmet'], 'yas': [25, 65]}

# %%
import pandas as pd

# %%
data2 = {"isim": ["ahmet", 'mehmet'],
       'yas' : [25,65]}

# %%
data2
# Out:
# {'isim': ['ahmet', 'mehmet'], 'yas': [25, 65]}

# %%
dataframe = pd.DataFrame(data2)
data2
# Out:
# {'isim': ['ahmet', 'mehmet'], 'yas': [25, 65]}

# %%
print(data2)
# Out:
# {'isim': ['ahmet', 'mehmet'], 'yas': [25, 65]}

# %%
dataframe = pd.read_csv('titanic.csv')

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataframe2 = pd.read_csv('titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dataframe2 = pd.read_csv('titanic.csv',index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
dataframe.to_excel('deneme.xlsx',index = False)

# %%
dataframe.to_excel('deneme2.xlsx',index = True)

# %%
test = dataframe['Pclass']

# %%
test
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
test_age = dataframe[dataframe['Age']<25]

# %%
test_age
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0              1         0       3              Braund, Mr. Owen Harris
# 7              8         0       3       Palsson, Master. Gosta Leonard
# 9             10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3      Sandstrom, Miss. Marguerite Rut
# 12            13         0       3       Saundercock, Mr. William Henry
# ..           ...       ...     ...                                  ...
# 875          876         1       3     Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3        Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                 Petroff, Mr. Nedelio
# 882          883         0       3         Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1         Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
dataframe['test'] = 1

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataframe['test2'] = 'Etu-FÜ'

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataframe['Age2'] = dataframe['Age'] * 2

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  44.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  76.0      1
# 2                               Heikkinen, Miss. Laina  female  52.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  70.0      1
# 4                             Allen, Mr. William Henry    male  70.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataframe['name-Sex'] = dataframe['Name'] + ' ' + dataframe['Sex']

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  44.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  76.0      1
# 2                               Heikkinen, Miss. Laina  female  52.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  70.0      1
# 4                             Allen, Mr. William Henry    male  70.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sub_set = dataframe[['Name', 'Parch']]

# %%
sub_set
# Out:
#                                                   Name  Parch
# 0                              Braund, Mr. Owen Harris      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 2                               Heikkinen, Miss. Laina      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0
# 4                             Allen, Mr. William Henry      0
# ..                                                 ...    ...
# 886                              Montvila, Rev. Juozas      0
# 887                       Graham, Miss. Margaret Edith      0
# 888           Johnston, Miss. Catherine Helen "Carrie"      2
# 889                              Behr, Mr. Karl Howell      0
# 890                                Dooley, Mr. Patrick      0
#
# [891 rows x 2 columns]
